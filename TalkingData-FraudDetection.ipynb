# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_sample = pd.read_csv('Data/train_sample.csv', parse_dates=True)
train_sample.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
clicktime = pd.DataFrame(train_sample, columns = ['click_time'])
clicktime.head()
# Out:
#             click_time
# 0  2017-11-07 09:30:38
# 1  2017-11-07 13:40:27
# 2  2017-11-07 18:05:24
# 3  2017-11-07 04:58:08
# 4  2017-11-09 09:00:09

# %%
clicktime.dtypes
# Out:
# click_time    object
# dtype: object

# %%
clicktime['click_time'] = clicktime['click_time'].astype('datetime64[ns]')

# %%
unique_clicks = pd.Series(clicktime['click_time'].value_counts())

# %%
unique_clicks
# Out:
# 2017-11-08 12:01:02    7
# 2017-11-08 13:32:05    6
# 2017-11-07 05:00:11    6
# 2017-11-09 14:46:23    6
# 2017-11-07 04:36:16    6
#                       ..
# 2017-11-09 05:49:05    1
# 2017-11-07 09:49:49    1
# 2017-11-08 09:02:12    1
# 2017-11-08 23:41:36    1
# 2017-11-09 08:00:11    1
# Name: click_time, Length: 80350, dtype: int64

# %%
unique_clicks.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_day = unique_clicks['2017-11-08 00:00:00':'2017-11-08 23:59:59']
subset_highest_day.head()
# Out:
# 2017-11-08 12:01:02    7
# 2017-11-08 13:32:05    6
# 2017-11-08 08:02:00    5
# 2017-11-08 06:13:02    5
# 2017-11-08 06:49:04    5
# Name: click_time, dtype: int64

# %%
subset_highest_day.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_hour = unique_clicks['2017-11-08 12:00:00':'2017-11-08 13:00:00']
subset_highest_hour.head()
# Out:
# 2017-11-08 12:01:02    7
# 2017-11-08 12:51:23    4
# 2017-11-08 12:14:44    4
# 2017-11-08 12:36:29    4
# 2017-11-08 12:45:59    4
# Name: click_time, dtype: int64

# %%
subset_highest_hour.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_10mins = unique_clicks['2017-11-08 12:00:00':'2017-11-08 12:10:00']
subset_highest_10mins.head()
# Out:
# 2017-11-08 12:01:02    7
# 2017-11-08 12:01:26    3
# 2017-11-08 12:04:54    3
# 2017-11-08 12:09:25    3
# 2017-11-08 12:05:34    3
# Name: click_time, dtype: int64

# %%
subset_highest_10mins.plot(kind='line', figsize=(20,10))
plt.show()

# %%
train_data = pd.read_csv('Data/train.csv', parse_dates=True)
train_data.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   83230    3       1  13      379  2017-11-06 14:32:21             NaN
# 1   17357    3       1  19      379  2017-11-06 14:33:34             NaN
# 2   35810    3       1  13      379  2017-11-06 14:34:12             NaN
# 3   45745   14       1  13      478  2017-11-06 14:34:52             NaN
# 4  161007    3       1  13      379  2017-11-06 14:35:08             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
train_data.shape
# Out:
# (184903890, 8)

# %%
clicktime = pd.DataFrame(train_data, columns = ['click_time'])
clicktime.head()
# Out:
#             click_time
# 0  2017-11-06 14:32:21
# 1  2017-11-06 14:33:34
# 2  2017-11-06 14:34:12
# 3  2017-11-06 14:34:52
# 4  2017-11-06 14:35:08

# %%
clicktime['click_time'] = clicktime['click_time'].astype('datetime64[ns]')

# %%
unique_clicks = pd.Series(clicktime['click_time'].value_counts())

# %%
unique_clicks
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-08 14:00:16    1497
# 2017-11-07 05:00:18    1494
# 2017-11-08 03:00:07    1491
# 2017-11-07 11:00:21    1474
#                        ...
# 2017-11-06 15:48:54       1
# 2017-11-06 15:59:16       1
# 2017-11-06 15:55:37       1
# 2017-11-06 15:44:34       1
# 2017-11-06 15:59:54       1
# Name: click_time, Length: 259620, dtype: int64

# %%
unique_clicks.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_day = unique_clicks['2017-11-07 00:00:00':'2017-11-07 23:59:59']
subset_highest_day.head()
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-07 05:00:18    1494
# 2017-11-07 11:00:21    1474
# 2017-11-07 05:00:15    1463
# 2017-11-07 09:00:10    1450
# Name: click_time, dtype: int64

# %%
subset_highest_day.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_hour = unique_clicks['2017-11-07 14:00:00':'2017-11-07 15:00:00']
subset_highest_hour.head()
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-07 14:00:12    1436
# 2017-11-07 14:00:10    1399
# 2017-11-07 14:00:09    1399
# 2017-11-07 14:00:15    1395
# Name: click_time, dtype: int64

# %%
subset_highest_hour.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_10mins = unique_clicks['2017-11-07 14:00:00':'2017-11-07 14:10:00']
subset_highest_10mins.head()
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-07 14:00:12    1436
# 2017-11-07 14:00:10    1399
# 2017-11-07 14:00:09    1399
# 2017-11-07 14:00:15    1395
# Name: click_time, dtype: int64

# %%
subset_highest_10mins.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_2mins = unique_clicks['2017-11-07 14:00:00':'2017-11-07 14:02:00']
subset_highest_2mins.head()
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-07 14:00:12    1436
# 2017-11-07 14:00:10    1399
# 2017-11-07 14:00:09    1399
# 2017-11-07 14:00:15    1395
# Name: click_time, dtype: int64

# %%
subset_highest_2mins.plot(kind='line', figsize=(20,10))
plt.show()

# %%
subset_highest_20secs = unique_clicks['2017-11-07 14:00:00':'2017-11-07 14:00:20']
subset_highest_20secs.head()
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-07 14:00:12    1436
# 2017-11-07 14:00:10    1399
# 2017-11-07 14:00:09    1399
# 2017-11-07 14:00:15    1395
# Name: click_time, dtype: int64

# %%
subset_highest_20secs.plot(kind='line', figsize=(20,10))
plt.show()
